# %%
# Import the dependencies.
import pandas as pd
import numpy as np
from citipy import citipy
import requests
import time
from datetime import datetime
from config import weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

#Unzip the package into a readable list
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 734

# %%
# Perform an API call with the OpenWeatherMap.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
#Retrieve latitude, longitude, maximum temperature, percent humidity, percent cludiness, wind speed, and weather description from the API call
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        description = city_weather["weather"][0]["description"]
        
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Weather Description": description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | saldanha
# Processing Record 2 of Set 1 | amapa
# Processing Record 3 of Set 1 | yellowknife
# Processing Record 4 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 5 of Set 1 | pyaozerskiy
# Processing Record 6 of Set 1 | rikitea
# Processing Record 7 of Set 1 | kapaa
# Processing Record 8 of Set 1 | mataura
# Processing Record 9 of Set 1 | saskylakh
# Processing Record 10 of Set 1 | dawson creek
# Processing Record 11 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 12 of Set 1 | beidao
# Processing Record 13 of Set 1 | hilo
# Processing Record 14 of Set 1 | vyatskiye polyany
# Processing Record 15 of Set 1 | tuktoyaktuk
# Processing Record 16 of Set 1 | ushuaia
# Processing Record 17 of Set 1 | labuhan
# Processing Record 18 of Set 1 | tilichiki
# Processing Record 19 of Set 1 | port elizabeth
# Processing Record 20 of Set 1 | barrow
# Processing Record 21 of Set 1 | oksfjord
# Processing Record 22 of Set 1 | souillac
# Processing Record 23 of Set 1 | nanortalik
# Processing Record 24 of Set 1 | atuona
# Processing Record 25 of Set 1 | norman wells
# Processing Record 26 of Set 1 | dikson
# Processing Record 27 of Set 1 | tiksi
# Processing Record 28 of Set 1 | tasiilaq
# Processing Record 29 of Set 1 | albany
# Processing Record 30 of Set 1 | chuy
# Processing Record 31 of Set 1 | sambava
# Processing Record 32 of Set 1 | kathu
# Processing Record 33 of Set 1 | ribeira grande
# Processing Record 34 of Set 1 | butaritari
# Processing Record 35 of Set 1 | kaitangata
# Processing Record 36 of Set 1 | fortuna
# Processing Record 37 of Set 1 | tucurui
# Processing Record 38 of Set 1 | tottori
# Processing Record 39 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 40 of Set 1 | kavieng
# Processing Record 41 of Set 1 | olga
# Processing Record 42 of Set 1 | bilibino
# Processing Record 43 of Set 1 | sitka
# Processing Record 44 of Set 1 | saint george
# Processing Record 45 of Set 1 | oussouye
# Processing Record 46 of Set 1 | hermanus
# Processing Record 47 of Set 1 | arraial do cabo
# Processing Record 48 of Set 1 | kavaratti
# Processing Record 49 of Set 1 | sao filipe
# Processing Record 50 of Set 1 | tandil
# Processing Record 1 of Set 2 | louisbourg
# City not found. Skipping...
# Processing Record 2 of Set 2 | imbituba
# Processing Record 3 of Set 2 | georgetown
# Processing Record 4 of Set 2 | jamestown
# Processing Record 5 of Set 2 | hongjiang
# Processing Record 6 of Set 2 | honningsvag
# Processing Record 7 of Set 2 | pisco
# Processing Record 8 of Set 2 | vaini
# Processing Record 9 of Set 2 | gurskoye
# City not found. Skipping...
# Processing Record 10 of Set 2 | coquimbo
# Processing Record 11 of Set 2 | olafsvik
# Processing Record 12 of Set 2 | cape town
# Processing Record 13 of Set 2 | hobart
# Processing Record 14 of Set 2 | new norfolk
# Processing Record 15 of Set 2 | mitsamiouli
# Processing Record 16 of Set 2 | bluff
# Processing Record 17 of Set 2 | puerto ayora
# Processing Record 18 of Set 2 | mar del plata
# Processing Record 19 of Set 2 | tommot
# Processing Record 20 of Set 2 | charleston
# Processing Record 21 of Set 2 | damavand
# Processing Record 22 of Set 2 | bambous virieux
# Processing Record 23 of Set 2 | volchikha
# Processing Record 24 of Set 2 | okhotsk
# Processing Record 25 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 26 of Set 2 | provideniya
# Processing Record 27 of Set 2 | bredasdorp
# Processing Record 28 of Set 2 | furstenfeldbruck
# City not found. Skipping...
# Processing Record 29 of Set 2 | qaanaaq
# Processing Record 30 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 31 of Set 2 | makaryev
# Processing Record 32 of Set 2 | matagami
# Processing Record 33 of Set 2 | castro
# Processing Record 34 of Set 2 | narsaq
# Processing Record 35 of Set 2 | port alfred
# Processing Record 36 of Set 2 | beyneu
# Processing Record 37 of Set 2 | carutapera
# Processing Record 38 of Set 2 | hylkje
# Processing Record 39 of Set 2 | cabinda
# Processing Record 40 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 41 of Set 2 | balikpapan
# Processing Record 42 of Set 2 | karasjok
# Processing Record 43 of Set 2 | palmer
# Processing Record 44 of Set 2 | shingu
# Processing Record 45 of Set 2 | carnarvon
# Processing Record 46 of Set 2 | luderitz
# Processing Record 47 of Set 2 | nikolskoye
# Processing Record 48 of Set 2 | mahebourg
# Processing Record 49 of Set 2 | alta floresta
# Processing Record 50 of Set 2 | stanislav
# Processing Record 1 of Set 3 | tecoanapa
# Processing Record 2 of Set 3 | busselton
# Processing Record 3 of Set 3 | motygino
# Processing Record 4 of Set 3 | ruatoria
# City not found. Skipping...
# Processing Record 5 of Set 3 | nova olinda do norte
# Processing Record 6 of Set 3 | rafai
# Processing Record 7 of Set 3 | avarua
# Processing Record 8 of Set 3 | along
# Processing Record 9 of Set 3 | cap-aux-meules
# Processing Record 10 of Set 3 | marabba
# Processing Record 11 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 12 of Set 3 | kendari
# Processing Record 13 of Set 3 | puerto escondido
# Processing Record 14 of Set 3 | berlin
# Processing Record 15 of Set 3 | itarema
# Processing Record 16 of Set 3 | olinda
# Processing Record 17 of Set 3 | kodiak
# Processing Record 18 of Set 3 | gimbi
# Processing Record 19 of Set 3 | lebu
# Processing Record 20 of Set 3 | punta arenas
# Processing Record 21 of Set 3 | atar
# Processing Record 22 of Set 3 | luanda
# Processing Record 23 of Set 3 | fayaoue
# Processing Record 24 of Set 3 | saint-denis
# Processing Record 25 of Set 3 | bethel
# Processing Record 26 of Set 3 | san andres
# Processing Record 27 of Set 3 | padang
# Processing Record 28 of Set 3 | saint-philippe
# Processing Record 29 of Set 3 | domoni
# Processing Record 30 of Set 3 | byron bay
# Processing Record 31 of Set 3 | lysva
# Processing Record 32 of Set 3 | hasaki
# Processing Record 33 of Set 3 | banjar
# Processing Record 34 of Set 3 | dunedin
# Processing Record 35 of Set 3 | east london
# Processing Record 36 of Set 3 | lulea
# Processing Record 37 of Set 3 | karachi
# Processing Record 38 of Set 3 | havelock
# Processing Record 39 of Set 3 | agirish
# Processing Record 40 of Set 3 | ballina
# Processing Record 41 of Set 3 | pangnirtung
# Processing Record 42 of Set 3 | nokaneng
# Processing Record 43 of Set 3 | purpe
# Processing Record 44 of Set 3 | palora
# Processing Record 45 of Set 3 | hilpoltstein
# Processing Record 46 of Set 3 | vilyuysk
# Processing Record 47 of Set 3 | duz
# City not found. Skipping...
# Processing Record 48 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 49 of Set 3 | saint anthony
# Processing Record 50 of Set 3 | japura
# Processing Record 1 of Set 4 | chokurdakh
# Processing Record 2 of Set 4 | ponta do sol
# Processing Record 3 of Set 4 | muisne
# Processing Record 4 of Set 4 | laje
# Processing Record 5 of Set 4 | kollegal
# Processing Record 6 of Set 4 | murgab
# Processing Record 7 of Set 4 | quatre cocos
# Processing Record 8 of Set 4 | husavik
# Processing Record 9 of Set 4 | ginir
# Processing Record 10 of Set 4 | thompson
# Processing Record 11 of Set 4 | zelenoborskiy
# Processing Record 12 of Set 4 | katsuura
# Processing Record 13 of Set 4 | sabang
# Processing Record 14 of Set 4 | yerbogachen
# Processing Record 15 of Set 4 | guerrero negro
# Processing Record 16 of Set 4 | zarubino
# Processing Record 17 of Set 4 | antalaha
# Processing Record 18 of Set 4 | yatou
# Processing Record 19 of Set 4 | tamiahua
# Processing Record 20 of Set 4 | nisia floresta
# Processing Record 21 of Set 4 | dingle
# Processing Record 22 of Set 4 | esperance
# Processing Record 23 of Set 4 | mokhsogollokh
# Processing Record 24 of Set 4 | gamba
# Processing Record 25 of Set 4 | vardo
# Processing Record 26 of Set 4 | marsh harbour
# Processing Record 27 of Set 4 | eureka
# Processing Record 28 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 29 of Set 4 | cabo san lucas
# Processing Record 30 of Set 4 | killarney
# Processing Record 31 of Set 4 | kloulklubed
# Processing Record 32 of Set 4 | zhigansk
# Processing Record 33 of Set 4 | kruisfontein
# Processing Record 34 of Set 4 | prince albert
# Processing Record 35 of Set 4 | nago
# Processing Record 36 of Set 4 | ishigaki
# Processing Record 37 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 38 of Set 4 | torbay
# Processing Record 39 of Set 4 | juneau
# Processing Record 40 of Set 4 | acajutiba
# Processing Record 41 of Set 4 | te anau
# Processing Record 42 of Set 4 | portland
# Processing Record 43 of Set 4 | cidreira
# Processing Record 44 of Set 4 | victoria
# Processing Record 45 of Set 4 | brasilia
# Processing Record 46 of Set 4 | alofi
# Processing Record 47 of Set 4 | port hardy
# Processing Record 48 of Set 4 | qaqortoq
# Processing Record 49 of Set 4 | cazaje
# City not found. Skipping...
# Processing Record 50 of Set 4 | nyrob
# Processing Record 1 of Set 5 | ahipara
# Processing Record 2 of Set 5 | washougal
# Processing Record 3 of Set 5 | axim
# Processing Record 4 of Set 5 | uppsala
# Processing Record 5 of Set 5 | pevek
# Processing Record 6 of Set 5 | belushya guba
# City not found. Skipping...
# Processing Record 7 of Set 5 | conde
# Processing Record 8 of Set 5 | neryungri
# Processing Record 9 of Set 5 | tahoua
# Processing Record 10 of Set 5 | anju
# Processing Record 11 of Set 5 | leh
# Processing Record 12 of Set 5 | honiara
# Processing Record 13 of Set 5 | harper
# Processing Record 14 of Set 5 | lata
# Processing Record 15 of Set 5 | chama
# Processing Record 16 of Set 5 | prince rupert
# Processing Record 17 of Set 5 | geraldton
# Processing Record 18 of Set 5 | mocambique
# City not found. Skipping...
# Processing Record 19 of Set 5 | keti bandar
# Processing Record 20 of Set 5 | hithadhoo
# Processing Record 21 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 22 of Set 5 | omboue
# Processing Record 23 of Set 5 | pathein
# Processing Record 24 of Set 5 | saravan
# Processing Record 25 of Set 5 | umm kaddadah
# Processing Record 26 of Set 5 | tual
# Processing Record 27 of Set 5 | pilar
# Processing Record 28 of Set 5 | vila
# Processing Record 29 of Set 5 | pangkalanbuun
# Processing Record 30 of Set 5 | sinnamary
# Processing Record 31 of Set 5 | bathsheba
# Processing Record 32 of Set 5 | longyearbyen
# Processing Record 33 of Set 5 | ust-ishim
# Processing Record 34 of Set 5 | fort nelson
# Processing Record 35 of Set 5 | road town
# Processing Record 36 of Set 5 | xuddur
# Processing Record 37 of Set 5 | bengkulu
# Processing Record 38 of Set 5 | belaya gora
# Processing Record 39 of Set 5 | westport
# Processing Record 40 of Set 5 | meulaboh
# Processing Record 41 of Set 5 | fallon
# Processing Record 42 of Set 5 | sorumsand
# Processing Record 43 of Set 5 | bubaque
# Processing Record 44 of Set 5 | coihaique
# Processing Record 45 of Set 5 | iqaluit
# Processing Record 46 of Set 5 | dzhusaly
# City not found. Skipping...
# Processing Record 47 of Set 5 | marang
# Processing Record 48 of Set 5 | bijie
# Processing Record 49 of Set 5 | omsukchan
# Processing Record 50 of Set 5 | bagaha
# Processing Record 1 of Set 6 | airai
# Processing Record 2 of Set 6 | kuche
# City not found. Skipping...
# Processing Record 3 of Set 6 | askino
# Processing Record 4 of Set 6 | laguna
# Processing Record 5 of Set 6 | batagay-alyta
# Processing Record 6 of Set 6 | lushunkou
# City not found. Skipping...
# Processing Record 7 of Set 6 | pemangkat
# Processing Record 8 of Set 6 | faanui
# Processing Record 9 of Set 6 | batticaloa
# Processing Record 10 of Set 6 | muros
# Processing Record 11 of Set 6 | shenjiamen
# Processing Record 12 of Set 6 | ngorongoro
# Processing Record 13 of Set 6 | tarbert
# Processing Record 14 of Set 6 | dolinsk
# Processing Record 15 of Set 6 | candeias
# Processing Record 16 of Set 6 | cayenne
# Processing Record 17 of Set 6 | manta
# Processing Record 18 of Set 6 | cayambe
# Processing Record 19 of Set 6 | natal
# Processing Record 20 of Set 6 | rio grande
# Processing Record 21 of Set 6 | haines junction
# Processing Record 22 of Set 6 | babushkin
# Processing Record 23 of Set 6 | belawan
# Processing Record 24 of Set 6 | presidencia roque saenz pena
# Processing Record 25 of Set 6 | aripuana
# Processing Record 26 of Set 6 | pinega
# Processing Record 27 of Set 6 | mayo
# Processing Record 28 of Set 6 | broome
# Processing Record 29 of Set 6 | namibe
# Processing Record 30 of Set 6 | san lorenzo
# Processing Record 31 of Set 6 | la grande
# Processing Record 32 of Set 6 | salumbar
# Processing Record 33 of Set 6 | colquechaca
# Processing Record 34 of Set 6 | shirokiy
# Processing Record 35 of Set 6 | upernavik
# Processing Record 36 of Set 6 | saint-francois
# Processing Record 37 of Set 6 | yenagoa
# Processing Record 38 of Set 6 | mehamn
# Processing Record 39 of Set 6 | ostrovnoy
# Processing Record 40 of Set 6 | matai
# Processing Record 41 of Set 6 | hambantota
# Processing Record 42 of Set 6 | vao
# Processing Record 43 of Set 6 | zamora
# Processing Record 44 of Set 6 | changde
# Processing Record 45 of Set 6 | novyy urengoy
# Processing Record 46 of Set 6 | sturgis
# Processing Record 47 of Set 6 | nouadhibou
# Processing Record 48 of Set 6 | kanniyakumari
# Processing Record 49 of Set 6 | lere
# Processing Record 50 of Set 6 | sabha
# Processing Record 1 of Set 7 | taraz
# Processing Record 2 of Set 7 | popondetta
# Processing Record 3 of Set 7 | honavar
# Processing Record 4 of Set 7 | marsaxlokk
# Processing Record 5 of Set 7 | roros
# Processing Record 6 of Set 7 | mezen
# Processing Record 7 of Set 7 | bellevue
# Processing Record 8 of Set 7 | ulaangom
# Processing Record 9 of Set 7 | gazanjyk
# Processing Record 10 of Set 7 | tuatapere
# Processing Record 11 of Set 7 | acajutla
# Processing Record 12 of Set 7 | touros
# Processing Record 13 of Set 7 | faya
# Processing Record 14 of Set 7 | jalu
# Processing Record 15 of Set 7 | paso de carrasco
# Processing Record 16 of Set 7 | caravelas
# Processing Record 17 of Set 7 | misratah
# Processing Record 18 of Set 7 | tabou
# Processing Record 19 of Set 7 | northam
# Processing Record 20 of Set 7 | aswan
# Processing Record 21 of Set 7 | sao pedro do piaui
# Processing Record 22 of Set 7 | chumikan
# Processing Record 23 of Set 7 | santa maria
# Processing Record 24 of Set 7 | kalmunai
# Processing Record 25 of Set 7 | saint-pierre
# Processing Record 26 of Set 7 | sentyabrskiy
# City not found. Skipping...
# Processing Record 27 of Set 7 | bulolo
# Processing Record 28 of Set 7 | saint-leu
# Processing Record 29 of Set 7 | umea
# Processing Record 30 of Set 7 | abonnema
# Processing Record 31 of Set 7 | lagoa
# Processing Record 32 of Set 7 | port-gentil
# Processing Record 33 of Set 7 | khatanga
# Processing Record 34 of Set 7 | nantucket
# Processing Record 35 of Set 7 | manono
# Processing Record 36 of Set 7 | ilulissat
# Processing Record 37 of Set 7 | marzuq
# Processing Record 38 of Set 7 | perigueux
# Processing Record 39 of Set 7 | grindavik
# Processing Record 40 of Set 7 | san quintin
# Processing Record 41 of Set 7 | volnovakha
# Processing Record 42 of Set 7 | lucea
# Processing Record 43 of Set 7 | asau
# Processing Record 44 of Set 7 | andenes
# Processing Record 45 of Set 7 | inzer
# Processing Record 46 of Set 7 | horodyshche
# Processing Record 47 of Set 7 | saint-joseph
# Processing Record 48 of Set 7 | labytnangi
# Processing Record 49 of Set 7 | toliary
# City not found. Skipping...
# Processing Record 50 of Set 7 | toro
# Processing Record 1 of Set 8 | oum hadjer
# Processing Record 2 of Set 8 | nizhneyansk
# City not found. Skipping...
# Processing Record 3 of Set 8 | lolua
# City not found. Skipping...
# Processing Record 4 of Set 8 | dzhebariki-khaya
# Processing Record 5 of Set 8 | nanzhang
# Processing Record 6 of Set 8 | galveston
# Processing Record 7 of Set 8 | liepaja
# Processing Record 8 of Set 8 | great bend
# Processing Record 9 of Set 8 | soyo
# Processing Record 10 of Set 8 | port blair
# Processing Record 11 of Set 8 | auki
# Processing Record 12 of Set 8 | hervey bay
# Processing Record 13 of Set 8 | inirida
# Processing Record 14 of Set 8 | waipawa
# Processing Record 15 of Set 8 | elizabeth city
# Processing Record 16 of Set 8 | gizo
# Processing Record 17 of Set 8 | benghazi
# Processing Record 18 of Set 8 | pousat
# City not found. Skipping...
# Processing Record 19 of Set 8 | eydhafushi
# Processing Record 20 of Set 8 | santa lucia
# Processing Record 21 of Set 8 | clyde river
# Processing Record 22 of Set 8 | chicama
# Processing Record 23 of Set 8 | clarence town
# Processing Record 24 of Set 8 | kokopo
# Processing Record 25 of Set 8 | broken hill
# Processing Record 26 of Set 8 | vestmanna
# Processing Record 27 of Set 8 | camacha
# Processing Record 28 of Set 8 | calvinia
# Processing Record 29 of Set 8 | naze
# Processing Record 30 of Set 8 | baruun-urt
# Processing Record 31 of Set 8 | wuan
# Processing Record 32 of Set 8 | pacific grove
# Processing Record 33 of Set 8 | riaba
# City not found. Skipping...
# Processing Record 34 of Set 8 | tavda
# Processing Record 35 of Set 8 | grand gaube
# Processing Record 36 of Set 8 | litoral del san juan
# City not found. Skipping...
# Processing Record 37 of Set 8 | la ronge
# Processing Record 38 of Set 8 | flin flon
# Processing Record 39 of Set 8 | lompoc
# Processing Record 40 of Set 8 | oranjemund
# Processing Record 41 of Set 8 | jeremie
# Processing Record 42 of Set 8 | puri
# Processing Record 43 of Set 8 | lorengau
# Processing Record 44 of Set 8 | kieta
# Processing Record 45 of Set 8 | sao joao da barra
# Processing Record 46 of Set 8 | antofagasta
# Processing Record 47 of Set 8 | zhengjiatun
# Processing Record 48 of Set 8 | zhanaozen
# Processing Record 49 of Set 8 | madimba
# Processing Record 50 of Set 8 | hailar
# Processing Record 1 of Set 9 | yamada
# Processing Record 2 of Set 9 | vila velha
# Processing Record 3 of Set 9 | trinidad
# Processing Record 4 of Set 9 | khonuu
# City not found. Skipping...
# Processing Record 5 of Set 9 | ketchikan
# Processing Record 6 of Set 9 | nemuro
# Processing Record 7 of Set 9 | halalo
# City not found. Skipping...
# Processing Record 8 of Set 9 | odda
# Processing Record 9 of Set 9 | verkhnyachka
# Processing Record 10 of Set 9 | ngukurr
# City not found. Skipping...
# Processing Record 11 of Set 9 | avera
# Processing Record 12 of Set 9 | hofn
# Processing Record 13 of Set 9 | kirakira
# Processing Record 14 of Set 9 | basco
# Processing Record 15 of Set 9 | moose factory
# Processing Record 16 of Set 9 | santa cruz
# Processing Record 17 of Set 9 | holoby
# Processing Record 18 of Set 9 | voh
# Processing Record 19 of Set 9 | asfi
# Processing Record 20 of Set 9 | port hedland
# Processing Record 21 of Set 9 | severo-kurilsk
# Processing Record 22 of Set 9 | constitucion
# Processing Record 23 of Set 9 | lavrentiya
# Processing Record 24 of Set 9 | novyy yegorlyk
# Processing Record 25 of Set 9 | blackfoot
# Processing Record 26 of Set 9 | nguiu
# City not found. Skipping...
# Processing Record 27 of Set 9 | rubiataba
# Processing Record 28 of Set 9 | san pedro
# Processing Record 29 of Set 9 | flinders
# Processing Record 30 of Set 9 | berea
# Processing Record 31 of Set 9 | benalla
# Processing Record 32 of Set 9 | bardiyah
# Processing Record 33 of Set 9 | les cayes
# Processing Record 34 of Set 9 | miles city
# Processing Record 35 of Set 9 | hokitika
# Processing Record 36 of Set 9 | saint-georges
# Processing Record 37 of Set 9 | arrecife
# Processing Record 38 of Set 9 | hamilton
# Processing Record 39 of Set 9 | ligayan
# Processing Record 40 of Set 9 | hualmay
# Processing Record 41 of Set 9 | novouzensk
# Processing Record 42 of Set 9 | korla
# Processing Record 43 of Set 9 | salalah
# Processing Record 44 of Set 9 | mantua
# Processing Record 45 of Set 9 | hayden
# Processing Record 46 of Set 9 | kuchinarai
# Processing Record 47 of Set 9 | aklavik
# Processing Record 48 of Set 9 | helena
# Processing Record 49 of Set 9 | chara
# Processing Record 50 of Set 9 | keuruu
# Processing Record 1 of Set 10 | rocha
# Processing Record 2 of Set 10 | san policarpo
# Processing Record 3 of Set 10 | nagtipunan
# Processing Record 4 of Set 10 | tucuma
# Processing Record 5 of Set 10 | marcona
# City not found. Skipping...
# Processing Record 6 of Set 10 | havoysund
# Processing Record 7 of Set 10 | sawtell
# Processing Record 8 of Set 10 | pyinmana
# Processing Record 9 of Set 10 | san rafael
# Processing Record 10 of Set 10 | bihoro
# Processing Record 11 of Set 10 | poum
# Processing Record 12 of Set 10 | athabasca
# Processing Record 13 of Set 10 | talnakh
# Processing Record 14 of Set 10 | lahaina
# Processing Record 15 of Set 10 | samalaeulu
# City not found. Skipping...
# Processing Record 16 of Set 10 | los llanos de aridane
# Processing Record 17 of Set 10 | taltal
# Processing Record 18 of Set 10 | dicabisagan
# Processing Record 19 of Set 10 | moyale
# Processing Record 20 of Set 10 | odweyne
# Processing Record 21 of Set 10 | sakakah
# Processing Record 22 of Set 10 | keroka
# Processing Record 23 of Set 10 | atherton
# Processing Record 24 of Set 10 | nizwa
# Processing Record 25 of Set 10 | high prairie
# Processing Record 26 of Set 10 | praia
# Processing Record 27 of Set 10 | malwan
# City not found. Skipping...
# Processing Record 28 of Set 10 | sale
# Processing Record 29 of Set 10 | lagos
# Processing Record 30 of Set 10 | saint-augustin
# Processing Record 31 of Set 10 | conceicao do rio verde
# Processing Record 32 of Set 10 | tura
# Processing Record 33 of Set 10 | santa cruz de la palma
# Processing Record 34 of Set 10 | chase
# Processing Record 35 of Set 10 | pachino
# Processing Record 36 of Set 10 | bacuit
# City not found. Skipping...
# Processing Record 37 of Set 10 | jucurutu
# Processing Record 38 of Set 10 | roebourne
# Processing Record 39 of Set 10 | college
# Processing Record 40 of Set 10 | raton
# Processing Record 41 of Set 10 | kabansk
# Processing Record 42 of Set 10 | lar
# Processing Record 43 of Set 10 | garchitorena
# Processing Record 44 of Set 10 | canon city
# Processing Record 45 of Set 10 | kahului
# Processing Record 46 of Set 10 | devils lake
# Processing Record 47 of Set 10 | altea
# Processing Record 48 of Set 10 | qovlar
# Processing Record 49 of Set 10 | hirara
# Processing Record 50 of Set 10 | lufilufi
# Processing Record 1 of Set 11 | sokolo
# Processing Record 2 of Set 11 | dutlwe
# Processing Record 3 of Set 11 | santiago
# Processing Record 4 of Set 11 | kangaatsiaq
# Processing Record 5 of Set 11 | lienz
# Processing Record 6 of Set 11 | awbari
# Processing Record 7 of Set 11 | ondjiva
# Processing Record 8 of Set 11 | turukhansk
# Processing Record 9 of Set 11 | imeni poliny osipenko
# Processing Record 10 of Set 11 | laredo
# Processing Record 11 of Set 11 | monteagudo
# Processing Record 12 of Set 11 | mbini
# Processing Record 13 of Set 11 | cockburn town
# Processing Record 14 of Set 11 | dera ghazi khan
# Processing Record 15 of Set 11 | klaksvik
# Processing Record 16 of Set 11 | papasquiaro
# City not found. Skipping...
# Processing Record 17 of Set 11 | ambilobe
# Processing Record 18 of Set 11 | grenville
# Processing Record 19 of Set 11 | burnie
# Processing Record 20 of Set 11 | eyrarbakki
# Processing Record 21 of Set 11 | coldingham
# Processing Record 22 of Set 11 | jieshi
# Processing Record 23 of Set 11 | belyy yar
# Processing Record 24 of Set 11 | durant
# Processing Record 25 of Set 11 | noumea
# Processing Record 26 of Set 11 | lavumisa
# Processing Record 27 of Set 11 | constantine
# Processing Record 28 of Set 11 | kosh-agach
# Processing Record 29 of Set 11 | yar-sale
# Processing Record 30 of Set 11 | azimur
# City not found. Skipping...
# Processing Record 31 of Set 11 | alexandria
# Processing Record 32 of Set 11 | rio gallegos
# Processing Record 33 of Set 11 | la gaulette
# City not found. Skipping...
# Processing Record 34 of Set 11 | praya
# Processing Record 35 of Set 11 | iskilip
# Processing Record 36 of Set 11 | sur
# Processing Record 37 of Set 11 | canberra
# Processing Record 38 of Set 11 | gangarampur
# Processing Record 39 of Set 11 | buala
# Processing Record 40 of Set 11 | dongsheng
# Processing Record 41 of Set 11 | liverpool
# Processing Record 42 of Set 11 | verkhnevilyuysk
# Processing Record 43 of Set 11 | rio pomba
# Processing Record 44 of Set 11 | springfield
# Processing Record 45 of Set 11 | adrar
# Processing Record 46 of Set 11 | roseburg
# Processing Record 47 of Set 11 | vila do maio
# Processing Record 48 of Set 11 | maceio
# Processing Record 49 of Set 11 | elvas
# Processing Record 50 of Set 11 | teterow
# Processing Record 1 of Set 12 | raudeberg
# Processing Record 2 of Set 12 | artyk
# City not found. Skipping...
# Processing Record 3 of Set 12 | chiang rai
# Processing Record 4 of Set 12 | podgorica
# Processing Record 5 of Set 12 | emerald
# Processing Record 6 of Set 12 | sao felix do xingu
# Processing Record 7 of Set 12 | fukuma
# Processing Record 8 of Set 12 | bambanglipuro
# Processing Record 9 of Set 12 | longjiang
# Processing Record 10 of Set 12 | santa pola
# Processing Record 11 of Set 12 | lakes entrance
# Processing Record 12 of Set 12 | comodoro rivadavia
# Processing Record 13 of Set 12 | lasa
# Processing Record 14 of Set 12 | ayia marina
# Processing Record 15 of Set 12 | saryozek
# Processing Record 16 of Set 12 | visnes
# Processing Record 17 of Set 12 | ingham
# Processing Record 18 of Set 12 | fredericksburg
# Processing Record 19 of Set 12 | ixtapa
# Processing Record 20 of Set 12 | hami
# Processing Record 21 of Set 12 | oyama
# Processing Record 22 of Set 12 | shimoda
# Processing Record 23 of Set 12 | puerto leguizamo
# Processing Record 24 of Set 12 | gat
# Processing Record 25 of Set 12 | sorland
# Processing Record 26 of Set 12 | margate
# Processing Record 27 of Set 12 | maniitsoq
# Processing Record 28 of Set 12 | hisor
# Processing Record 29 of Set 12 | santa barbara
# Processing Record 30 of Set 12 | faranah
# Processing Record 31 of Set 12 | half moon bay
# Processing Record 32 of Set 12 | mackay
# Processing Record 33 of Set 12 | svetlogorsk
# Processing Record 34 of Set 12 | chulym
# Processing Record 35 of Set 12 | jinchang
# Processing Record 36 of Set 12 | gari
# Processing Record 37 of Set 12 | creel
# Processing Record 38 of Set 12 | cherskiy
# Processing Record 39 of Set 12 | klobuck
# Processing Record 40 of Set 12 | nome
# Processing Record 41 of Set 12 | mergui
# City not found. Skipping...
# Processing Record 42 of Set 12 | youghal
# Processing Record 43 of Set 12 | meyungs
# City not found. Skipping...
# Processing Record 44 of Set 12 | solsvik
# City not found. Skipping...
# Processing Record 45 of Set 12 | morogoro
# Processing Record 46 of Set 12 | karratha
# Processing Record 47 of Set 12 | anadyr
# Processing Record 48 of Set 12 | atbasar
# Processing Record 49 of Set 12 | san patricio
# Processing Record 50 of Set 12 | kamina
# Processing Record 1 of Set 13 | calbuco
# Processing Record 2 of Set 13 | petauke
# Processing Record 3 of Set 13 | suao
# City not found. Skipping...
# Processing Record 4 of Set 13 | fort-shevchenko
# Processing Record 5 of Set 13 | envira
# Processing Record 6 of Set 13 | tatawin
# Processing Record 7 of Set 13 | bowen
# Processing Record 8 of Set 13 | sioux lookout
# Processing Record 9 of Set 13 | marawi
# Processing Record 10 of Set 13 | dubbo
# Processing Record 11 of Set 13 | green river
# Processing Record 12 of Set 13 | sorvag
# City not found. Skipping...
# Processing Record 13 of Set 13 | dandeli
# Processing Record 14 of Set 13 | rio verde de mato grosso
# Processing Record 15 of Set 13 | cuamba
# Processing Record 16 of Set 13 | namatanai
# Processing Record 17 of Set 13 | sungaipenuh
# Processing Record 18 of Set 13 | kilindoni
# Processing Record 19 of Set 13 | port lincoln
# Processing Record 20 of Set 13 | suntar
# Processing Record 21 of Set 13 | kollumerland
# City not found. Skipping...
# Processing Record 22 of Set 13 | san cristobal
# Processing Record 23 of Set 13 | punta alta
# Processing Record 24 of Set 13 | lazaro cardenas
# Processing Record 25 of Set 13 | changqing
# Processing Record 26 of Set 13 | prince george
# Processing Record 27 of Set 13 | nelson bay
# Processing Record 28 of Set 13 | port-de-bouc
# Processing Record 29 of Set 13 | martapura
# Processing Record 30 of Set 13 | luancheng
# Processing Record 31 of Set 13 | kota kinabalu
# Processing Record 32 of Set 13 | waitati
# Processing Record 33 of Set 13 | jatara
# Processing Record 34 of Set 13 | umzimvubu
# City not found. Skipping...
# Processing Record 35 of Set 13 | terrace
# Processing Record 36 of Set 13 | bayan
# Processing Record 37 of Set 13 | nabire
# Processing Record 38 of Set 13 | bodden town
# Processing Record 39 of Set 13 | jiuquan
# Processing Record 40 of Set 13 | pemberton
# Processing Record 41 of Set 13 | luba
# Processing Record 42 of Set 13 | vestmannaeyjar
# Processing Record 43 of Set 13 | conceicao do mato dentro
# Processing Record 44 of Set 13 | kita
# Processing Record 45 of Set 13 | mount gambier
# Processing Record 46 of Set 13 | uvinza
# Processing Record 47 of Set 13 | talara
# Processing Record 48 of Set 13 | ostersund
# Processing Record 49 of Set 13 | itaituba
# Processing Record 50 of Set 13 | saryshagan
# City not found. Skipping...
# Processing Record 1 of Set 14 | kalabagh
# Processing Record 2 of Set 14 | fairbanks
# Processing Record 3 of Set 14 | boulder city
# Processing Record 4 of Set 14 | venado tuerto
# Processing Record 5 of Set 14 | tupik
# Processing Record 6 of Set 14 | dzaoudzi
# Processing Record 7 of Set 14 | gopalur
# Processing Record 8 of Set 14 | sibolga
# Processing Record 9 of Set 14 | payo
# Processing Record 10 of Set 14 | mount isa
# Processing Record 11 of Set 14 | zelezniki
# Processing Record 12 of Set 14 | araguacu
# Processing Record 13 of Set 14 | ilo
# Processing Record 14 of Set 14 | mercedes
# Processing Record 15 of Set 14 | paeroa
# Processing Record 16 of Set 14 | vorozhba
# Processing Record 17 of Set 14 | humaita
# Processing Record 18 of Set 14 | lawrenceburg
# Processing Record 19 of Set 14 | alice springs
# Processing Record 20 of Set 14 | pascagoula
# Processing Record 21 of Set 14 | porto novo
# Processing Record 22 of Set 14 | matara
# Processing Record 23 of Set 14 | linxia
# Processing Record 24 of Set 14 | ancud
# Processing Record 25 of Set 14 | bagdarin
# Processing Record 26 of Set 14 | espanola
# Processing Record 27 of Set 14 | san jose
# Processing Record 28 of Set 14 | lashio
# Processing Record 29 of Set 14 | takoradi
# Processing Record 30 of Set 14 | leningradskiy
# Processing Record 31 of Set 14 | raga
# Processing Record 32 of Set 14 | collie
# Processing Record 33 of Set 14 | tautira
# Processing Record 34 of Set 14 | peniche
# Processing Record 35 of Set 14 | adelanto
# Processing Record 36 of Set 14 | areka
# Processing Record 37 of Set 14 | moron
# Processing Record 38 of Set 14 | ganzhou
# Processing Record 39 of Set 14 | komsomolskiy
# Processing Record 40 of Set 14 | venice
# Processing Record 41 of Set 14 | ucluelet
# Processing Record 42 of Set 14 | wainwright
# Processing Record 43 of Set 14 | ligatne
# Processing Record 44 of Set 14 | mavrovi anovi
# Processing Record 45 of Set 14 | kaeo
# Processing Record 46 of Set 14 | dianopolis
# City not found. Skipping...
# Processing Record 47 of Set 14 | kapustin yar
# Processing Record 48 of Set 14 | valdivia
# Processing Record 49 of Set 14 | poyarkovo
# Processing Record 50 of Set 14 | taoudenni
# Processing Record 1 of Set 15 | seoul
# Processing Record 2 of Set 15 | cabedelo
# Processing Record 3 of Set 15 | praia da vitoria
# Processing Record 4 of Set 15 | nam som
# Processing Record 5 of Set 15 | rawson
# Processing Record 6 of Set 15 | san felipe
# Processing Record 7 of Set 15 | sembe
# Processing Record 8 of Set 15 | keflavik
# Processing Record 9 of Set 15 | palabuhanratu
# City not found. Skipping...
# Processing Record 10 of Set 15 | issia
# Processing Record 11 of Set 15 | coahuayana
# Processing Record 12 of Set 15 | santiago de cuba
# Processing Record 13 of Set 15 | kollam
# Processing Record 14 of Set 15 | hobyo
# Processing Record 15 of Set 15 | elat
# Processing Record 16 of Set 15 | susuman
# Processing Record 17 of Set 15 | koslan
# Processing Record 18 of Set 15 | tignere
# Processing Record 19 of Set 15 | kytlym
# City not found. Skipping...
# Processing Record 20 of Set 15 | barbar
# City not found. Skipping...
# Processing Record 21 of Set 15 | berlevag
# Processing Record 22 of Set 15 | escarcega
# Processing Record 23 of Set 15 | svetlyy
# Processing Record 24 of Set 15 | shelburne
# Processing Record 25 of Set 15 | egvekinot
# Processing Record 26 of Set 15 | verkhniy mamon
# Processing Record 27 of Set 15 | lucapa
# Processing Record 28 of Set 15 | kamenka
# Processing Record 29 of Set 15 | ottawa
# Processing Record 30 of Set 15 | uyovu
# Processing Record 31 of Set 15 | qui nhon
# Processing Record 32 of Set 15 | guhagar
# Processing Record 33 of Set 15 | laranja da terra
# Processing Record 34 of Set 15 | bairiki
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
#Add data to a Pandas Dataframe
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Saldanha      ZA -33.0117   17.9442     65.88        59           0
# 1         Amapa      BR   1.0000  -52.0000     73.18        98          94
# 2   Yellowknife      CA  62.4560 -114.3525     15.57        56          93
# 3   Pyaozerskiy      RU  65.8333   31.1667     31.23        88          93
# 4       Rikitea      PF -23.1203 -134.9692     79.21        71           1
# 5         Kapaa      US  22.0752 -159.3190     84.18        72           0
# 6       Mataura      NZ -46.1927  168.8643     54.48        92          98
# 7     Saskylakh      RU  71.9167  114.0833     -3.66        98         100
# 8  Dawson Creek      CA  55.7666 -120.2362     19.04        63         100
# 9        Beidao      CN  34.5686  105.8933     48.97        72         100
#
#    Wind Speed   Weather Description
# 0        6.80             clear sky
# 1        3.65  heavy intensity rain
# 2       15.99       overcast clouds
# 3       10.87       overcast clouds
# 4       15.01             clear sky
# 5       10.36             clear sky
# 6        6.29       overcast clouds
# 7        2.35       overcast clouds
# 8       13.80       overcast clouds
# 9        1.21       overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the DataFrame as a CSV file.
city_data_df.to_csv(output_data_file, index_label="City_ID")
